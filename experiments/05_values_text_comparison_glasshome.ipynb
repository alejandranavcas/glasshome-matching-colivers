# %% [markdown]
# # Compare texts with Glasshome values

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df_texts_glasshome = pd.read_csv('values_glasshome.csv')
df_texts = pd.read_csv('values_scraped_comments_thephilosophyforum.csv')

# %%
# add as extra row the glasshome values
df = pd.concat([df_texts, df_texts_glasshome], ignore_index=True)

# add user_id when is Nan
df['user_id'] = df.apply(lambda row: 'glasshome' if pd.isna(row['user_id']) else row['user_id'], axis=1)
df
# Out:
#       user_id            author  \
# 0         1.0                BC
# 1         2.0      I like sushi
# 2         3.0             Janus
# 3         4.0             Joshs
# 4         5.0            Judaka
# 5         6.0       Possibility
# 6         7.0        RegularGuy
# 7         8.0                 S
# 8         9.0             Shawn
# 9        10.0           T Clark
# 10       11.0  Terrapin Station
# 11       12.0   VagabondSpectre
# 12       13.0        ZhouBoTong
# 13       14.0            praxis
# 14       15.0               ssu
# 15  glasshome               NaN
# 16  glasshome               NaN
# 17  glasshome               NaN
# 18  glasshome               NaN
# 19  glasshome               NaN
#
#                                            value_text                category
# 0   obedient ... reverent ... capitalism—T ClarkAn...                     NaN
# 1   The basic principle of anarchism seems to be a...                     NaN
# 2   I have a feeling these are too simplistic and ...                     NaN
# 3   ↪T ClarkYou missed something here. You left ou...                     NaN
# 4   ↪T ClarkYou take anything and express all the ...                     NaN
# 5   Personally I see nationalism, patriotism and l...                     NaN
# 6   ↪T ClarkI value different things in different ...                     NaN
# 7   ↪T ClarkDiogenes and Nietzsche were good on va...                     NaN
# 8   I understand the importance of values; but, ho...                     NaN
# 9   In the last week or so, in several different c...                     NaN
# 10  ↪T ClarkIt's not clear to me what you're askin...                     NaN
# 11  ↪T ClarkSome of us will have conflicting value...                     NaN
# 12  So what are our values?—T ClarkWhat about thin...                     NaN
# 13  ↪T ClarkJudging by your declared values I woul...                     NaN
# 14  Here’s a list of the values of Western Culture...                     NaN
# 15  Togetherness: This is our commitment to buildi...            Togetherness
# 16  Genuine Individuality: We are empowering ourse...   Genuine Individuality
# 17  Serve Humanity: Loneliness, stress and planeta...          Serve humanity
# 18  Well being: For us this means to give ourselve...              Well being
# 19  Everyone is a designer: When we act from a pla...  Everyone is a designer

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### TF-IDF

# %%
# TF-idf
from aux_methods import vectorize_text_tfidf, plot_similarity_matrix

# Test the similarity matrix plotting
print("Values texts 1:")
sim_matrix, similarities = vectorize_text_tfidf(df)
user_ids = df['user_id'].tolist()
plot_similarity_matrix(similarities, user_ids)
# Out:
# Values texts 1:

# %% [markdown]
# ### BART

# %%
# BART MNLI zero-shot classification
from transformers import pipeline

# Load zero-shot classification pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
labels = ["security", "power", "achievement", "hedonism", "stimulation", "self-direction", "universalism", "benevolence", "tradition", "conformity"]
# Out:
# Device set to use cpu

# %%
# Run classification for all texts
texts = df['value_text'].tolist()
scores = np.zeros((len(texts), len(labels)))
for i, text in enumerate(texts):
    result = classifier(text, candidate_labels=labels)
    scores[i] = result['scores']

from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity
cosine_sim = cosine_similarity(scores)

# %%
# Friendly row/col labels
n = cosine_sim.shape[0]
labels = [f'User {i+1}' for i in range(n)]

# Simple heatmap
plt.figure(figsize=(8,6))
sns.heatmap(cosine_sim, xticklabels=labels, yticklabels=labels, annot=True, fmt=".2f",
            cmap="coolwarm", vmin=0, vmax=1, square=True, cbar_kws={"shrink":0.7})
plt.title("Cosine similarity between texts")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ME2-BERT
